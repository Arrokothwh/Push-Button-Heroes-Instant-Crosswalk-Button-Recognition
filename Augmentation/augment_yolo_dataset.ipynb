# %% [markdown]
# ## Notebook for augmenting images used for first stage YOLO model of 2-stage model pipline

# %%
# Check if all image have label or vice versa
import os

image_dir = "TwoStageYOLODataset/original/images"
label_dir = "TwoStageYOLODataset/original/labels"

# 获取不含扩展名的文件名集合
image_files = {os.path.splitext(f)[0] for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.png'))}
label_files = {os.path.splitext(f)[0] for f in os.listdir(label_dir) if f.lower().endswith('.txt')}

# 差集
images_without_labels = image_files - label_files
labels_without_images = label_files - image_files

# 打印结果
print(f"🔍 图像总数: {len(image_files)}")
print(f"📝 标签总数: {len(label_files)}\n")

print(f"📸 有图像但没有标签的数量: {len(images_without_labels)}")
for name in sorted(images_without_labels):
    print(f" - {name}.jpg")

print(f"\n🗂️ 有标签但没有图像的数量: {len(labels_without_images)}")
for name in sorted(labels_without_images):
    print(f" - {name}.txt")
# Out:
# 🔍 图像总数: 139
# 📝 标签总数: 139
#
# 📸 有图像但没有标签的数量: 0
#
# 🗂️ 有标签但没有图像的数量: 0

# %%
import os, itertools, copy
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm
import augment_utils_chain as aug

# 子集名称
subsets = ['train', 'val', 'test']

# 增强函数
AUG_FUNCS = [
    aug.add_gaussian_noise,
    aug.adjust_random_brightness,
    aug.add_black_rect,
    aug.horizontal_flip,
    aug.random_rotate,
    aug.random_scale_with_padding,
]

# 不建议同时用的组合
bad_pair = {aug.add_gaussian_noise, aug.random_scale_with_padding}


def process_one(name):
    try:
        img, boxes, cls, _, _ = aug.load_image_and_boxes(name)
        aug.save_augmented(img, boxes, cls, name)
        for combo in itertools.combinations(AUG_FUNCS, 4):
            if bad_pair.issubset(combo):
                continue
            img_aug, boxes_aug, cls_aug = copy.deepcopy(img), copy.deepcopy(boxes), cls
            for fn in combo:
                img_aug, boxes_aug, cls_aug = fn(img_aug, boxes_aug, cls_aug)
            aug.save_augmented(img_aug, boxes_aug, cls_aug, name)
    except Exception as e:
        print(f"[ERROR] {name}: {e}")


for subset in subsets:
    print(f"\n🚀 Processing {subset} set...")

    # 设置路径
    aug.INPUT_DIR = f"TwoStageYOLODataset/squared"
    aug.OUTPUT_DIR = f"TwoStageYOLODataset/augmented"

    image_subdir = os.path.join(aug.INPUT_DIR, "images", subset)
    label_subdir = os.path.join(aug.INPUT_DIR, "labels", subset)

    # 重写 load/save 函数需要 subset 上下文 —— 我们把 subset 添加进文件名
    img_names = [
        os.path.join(subset, os.path.splitext(f)[0])
        for f in os.listdir(image_subdir)
        if f.lower().endswith(".jpg")
    ]

    # 多线程处理
    with ThreadPoolExecutor(max_workers=20) as ex:
        list(tqdm(ex.map(process_one, img_names), total=len(img_names)))
# Out:
# 🚀 Processing train set...
#   0%|          | 0/111 [00:00<?, ?it/s]
# 🚀 Processing val set...
#   0%|          | 0/13 [00:00<?, ?it/s]
# 🚀 Processing test set...
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# Convert to square image of 1440*1440
from PIL import Image, ImageOps
import os

def pad_to_square_and_update_yolo(img_path, label_path, output_img_dir, output_label_dir):
    img = Image.open(img_path)
    w, h = img.size  # Should be 1080x1440

    # Padding: add 180 pixels left/right to make it square
    delta_w = 1440 - w  # 360
    pad_left = delta_w // 2
    pad_right = delta_w - pad_left
    padding = (pad_left, 0, pad_right, 0)  # (left, top, right, bottom)
    padded_img = ImageOps.expand(img, padding, fill=(0, 0, 0))

    # Save padded image
    os.makedirs(output_img_dir, exist_ok=True)
    img_filename = os.path.basename(img_path)
    padded_img.save(os.path.join(output_img_dir, img_filename))

    # Adjust YOLO labels
    os.makedirs(output_label_dir, exist_ok=True)
    new_label_path = os.path.join(output_label_dir, os.path.basename(label_path))

    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            lines = f.readlines()

        new_lines = []
        for line in lines:
            cls, x, y, w_box, h_box = map(float, line.strip().split())

            # Convert to absolute coordinates
            x_abs = x * w
            y_abs = y * h
            w_abs = w_box * w
            h_abs = h_box * h

            # Shift x due to padding
            x_abs += pad_left

            # New normalized values (on 1440x1440)
            x_new = x_abs / 1440
            y_new = y_abs / 1440
            w_new = w_abs / 1440
            h_new = h_abs / 1440

            new_line = f"{int(cls)} {x_new:.6f} {y_new:.6f} {w_new:.6f} {h_new:.6f}"
            new_lines.append(new_line)

        with open(new_label_path, 'w') as f:
            f.write('\n'.join(new_lines))

        print(f"Padded + updated: {img_filename}")



input_img_dir = 'TwoStageYOLODataset/original/images'           # ← 输入图片路径
input_label_dir = 'TwoStageYOLODataset/original/labels'         # ← 输入 YOLO 标签路径（.txt）
output_img_dir = 'TwoStageYOLODataset/squared/images'         # ← 输出图片路径
output_label_dir = 'TwoStageYOLODataset/squared/labels'       # ← 输出标签路径

# 创建输出目录
os.makedirs(output_img_dir, exist_ok=True)
os.makedirs(output_label_dir, exist_ok=True)


# Call function for all images
for filename in os.listdir(input_img_dir):
    if not filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue
    img_path = os.path.join(input_img_dir, filename)
    label_path = os.path.join(input_label_dir, os.path.splitext(filename)[0] + '.txt')
    
    pad_to_square_and_update_yolo(
        img_path,
        label_path,
        output_img_dir,
        output_label_dir
    )
# Out:
# Padded + updated: 0024e2fb-IMG_20250504_163554.jpg
# Padded + updated: 044fe449-ca5db8ce3124515c2bb4cffbf83680d.jpg
# Padded + updated: 052b5e49-38ee20756033d13b0a5de48a476f372.jpg
# Padded + updated: 070cd6a7-IMG_20250515_114615.jpg
# Padded + updated: 07aa7552-20250510_183822.jpg
# Padded + updated: 07ce01d0-ecc48860-IMG_20250427_165039.jpg
# Padded + updated: 0ed66e0a-IMG_20250506_181958.jpg
# Padded + updated: 11dbab4c-602c2017-IMG_20250427_165342.jpg
# Padded + updated: 13e313c1-IMG_20250504_161424.jpg
# Padded + updated: 159e6cac-39a73c67c92fd9725c0d3a905edc124.jpg
# Padded + updated: 15e5e754-20250502_173131.jpg
# Padded + updated: 164a9ef9-f5e87f52272f6ea87994a5e548b5b1c.jpg
# Padded + updated: 17ff7546-5e168810-IMG_20250427_151613.jpg
# Padded + updated: 1b30ad36-acad2ddd8f04a9227d348fb8d41f296.jpg
# Padded + updated: 1d2253c9-b91cd0831e5e566042fca6d21900b2a.jpg
# Padded + updated: 1e977f20-cef8710a-IMG_20250427_152010.jpg
# Padded + updated: 222df708-894876bf-IMG_20250427_165035.jpg
# Padded + updated: 22e3fd33-IMG_20250503_134158.jpg
# Padded + updated: 23d7d687-IMG_20250504_161413.jpg
# Padded + updated: 25799444-a821fa8d98aa534bb000b6f09818e4a.jpg
# Padded + updated: 27ba5f5b-2a12af8b-IMG_20250427_151658.jpg
# Padded + updated: 28b77690-bf555a5c-IMG_20250427_165444.jpg
# Padded + updated: 2c6023a1-IMG_20250504_162229.jpg
# Padded + updated: 2cbaf99f-3f859605-IMG_20250427_161603.jpg
# Padded + updated: 2d7849d6-8affdb16d09e49f54ac2d11f263a04e.jpg
# Padded + updated: 2e2eac78-b4da9871-IMG_20250427_162122.jpg
# Padded + updated: 2fc49ea7-527b54a3b8069779ff1a206c0d313ac.jpg
# Padded + updated: 343165a6-848937a7-IMG_20250427_161929.jpg
# Padded + updated: 35f1c3b1-402386c1ada6e74850ca04b7042e09c.jpg
# Padded + updated: 36519896-IMG_20250504_161352.jpg
# Padded + updated: 380a15e0-IMG_20250504_163524.jpg
# Padded + updated: 386975b6-IMG_20250504_162243.jpg
# Padded + updated: 386e5391-bb88745e-IMG_20250427_161606.jpg
# Padded + updated: 38a89998-IMG_20250503_134403.jpg
# Padded + updated: 39ad6e36-736c46fb-IMG_20250427_165040.jpg
# Padded + updated: 3ac2bec3-695c7e4ead5118390eff7b32d6e1f0c.jpg
# Padded + updated: 3db9668d-IMG_20250504_163552.jpg
# Padded + updated: 3f1c2736-12e43fad6e577062c1d6c0737474b4b.jpg
# Padded + updated: 43b6999d-611cb5e7-IMG_20250427_165032.jpg
# Padded + updated: 459b688e-70081191-IMG_20250427_152218.jpg
# Padded + updated: 467dc529-IMG_20250504_162235.jpg
# Padded + updated: 469e6d3e-cd6c1028bce6dc0abbcad52dd634e55.jpg
# Padded + updated: 4c86e588-IMG_20250504_163551.jpg
# Padded + updated: 4d269290-542b5ed719a4b3703114f29f8392bd5.jpg
# Padded + updated: 529826ab-21e3e82b81ad6221694b8348fed32eb.jpg
# Padded + updated: 532b5e97-IMG_20250503_141619_2.jpg
# Padded + updated: 55ba4e80-fce64740-IMG_20250427_165448.jpg
# Padded + updated: 5667e9a4-fc7253f16ad6012c55bd83b4be004f0.jpg
# Padded + updated: 59215836-IMG_20250504_163526.jpg
# Padded + updated: 59cc02da-76213df95e1bdd923cfa70f8abd61e4.jpg
# Padded + updated: 5a9f41cc-IMG_20250506_165152.jpg
# Padded + updated: 5b9cb8dd-IMG_20250503_141613.jpg
# Padded + updated: 5fe4dbc0-eb520b4d7ff9b04f70b7ca2c0f94ede.jpg
# Padded + updated: 6221512c-a3b9b07c-IMG_20250427_151707.jpg
# Padded + updated: 6425f8d1-IMG_20250515_114610.jpg
# Padded + updated: 647f6b0f-5f4c36d71ade35eb78dce7368c3f8d1.jpg
# Padded + updated: 66d7f9f3-e3d6a0dc-IMG_20250427_151938.jpg
# Padded + updated: 68e1e2c3-60128d97-IMG_20250427_165243.jpg
# Padded + updated: 69805b37-20250502_173224.jpg
# Padded + updated: 6a9156cb-93249830-IMG_20250427_151945.jpg
# Padded + updated: 6d2874fd-f0891edf510df76706ed9a92d715c95.jpg
# Padded + updated: 6d64c343-9109e65f60fb27b3d8ca2083ae32bbe.jpg
# Padded + updated: 6e25cfd0-5fad4e6872142b67ec87ee047c68273.jpg
# Padded + updated: 6ed187af-IMG_20250506_181947.jpg
# Padded + updated: 6edaccd4-IMG_20250506_181958_1.jpg
# Padded + updated: 6f508bfd-668443bc-IMG_20250427_152235.jpg
# Padded + updated: 735b1f19-2b110264-IMG_20250427_152234.jpg
# Padded + updated: 7456969c-e211ef03-IMG_20250427_161624.jpg
# Padded + updated: 7778c593-20250502_161430.jpg
# Padded + updated: 786cdf81-d2fc2aa1-IMG_20250427_152014.jpg
# Padded + updated: 7a57bfa5-9d56879deab4b91c98149080d360421.jpg
# Padded + updated: 7d93d999-IMG_20250513_170944.jpg
# Padded + updated: 7f61dfce-7394962ddbfc6bbdfcc24c52080bbbc.jpg
# Padded + updated: 8253f90d-IMG_20250506_165207.jpg
# Padded + updated: 8378b380-ffe5358d68347348e9561adb0dfd176.jpg
# Padded + updated: 890270a5-4c2817b9-IMG_20250427_151953.jpg
# Padded + updated: 898896f8-IMG_20250510_193239.jpg
# Padded + updated: 8e0f248e-3f130c34-IMG_20250427_151949.jpg
# Padded + updated: 9267c415-20250510_183833.jpg
# Padded + updated: 92af7312-20250509_133931.jpg
# Padded + updated: 937a74a9-IMG_20250503_141619_1.jpg
# Padded + updated: 96aa2298-a7904ff0eeb590eeb439dcf4dba3e2a.jpg
# Padded + updated: 98753cf4-IMG_20250506_181935.jpg
# Padded + updated: 99b9c00d-IMG_20250503_134426.jpg
# Padded + updated: 9bc4646a-IMG_20250504_162249.jpg
# Padded + updated: 9c111671-1c83aa75754d0e06da1ab2174fbc9d3.jpg
# Padded + updated: 9cafec17-IMG_20250504_163532.jpg
# Padded + updated: 9e958331-IMG_20250504_162232.jpg
# Padded + updated: 9ed90c0b-IMG_20250503_134102.jpg
# Padded + updated: 9efe16e0-IMG_20250503_134145.jpg
# Padded + updated: 9fa0c14f-IMG_20250503_134119.jpg
# Padded + updated: a24c8122-IMG_20250513_170958.jpg
# Padded + updated: a71c96ee-IMG_20250503_134127.jpg
# Padded + updated: a74f55ce-20250510_183827.jpg
# Padded + updated: a7ec8333-20250502_133710.jpg
# Padded + updated: a8f494a1-IMG_20250506_165146.jpg
# Padded + updated: a9764772-76f6297d-IMG_20250427_184726.jpg
# Padded + updated: af9e4fd0-IMG_20250503_134200.jpg
# Padded + updated: b2e78122-9c0459df7fa0dc42d2b8b8e915152c2.jpg
# Padded + updated: b77f68a9-784b6a0fa103cd4f0a9135c6abcf95c.jpg
# Padded + updated: baa01dc7-b1c01f09b755fea623c620cbf72d160.jpg
# Padded + updated: bad16282-86bbb0e9-IMG_20250427_151959.jpg
# Padded + updated: bb50bd4d-2e93e0c3-IMG_20250427_184718.jpg
# Padded + updated: bc855ccb-20250502_161432.jpg
# Padded + updated: bee881a1-IMG_20250503_133216.jpg
# Padded + updated: c0ab99a8-379b9a5cce9148ce0a7305806a50424.jpg
# Padded + updated: c4f675b3-20250502_181555.jpg
# Padded + updated: c9b7276e-20250507_183621.jpg
# Padded + updated: ca2e6da5-IMG_20250503_134434.jpg
# Padded + updated: cb554ada-a92b30d1-IMG_20250427_165029.jpg
# Padded + updated: cc0c9914-20250507_123302.jpg
# Padded + updated: cd5a091c-86e41ef4bf9aacd20d274a60bfa3fb7.jpg
# Padded + updated: cdaa9c9f-5b67582e96e8ca90f74b493cdf15f40.jpg
# Padded + updated: ce7bfc14-71978ecf-IMG_20250427_161932.jpg
# Padded + updated: d1d1f980-IMG_20250503_134440.jpg
# Padded + updated: d51e63f6-20250507_183634.jpg
# Padded + updated: d5595093-e3bc7c46-IMG_20250427_152221.jpg
# Padded + updated: d60ad996-IMG_20250503_133157.jpg
# Padded + updated: d7412228-IMG_20250503_134456.jpg
# Padded + updated: d8444b42-a2313424923c740855531bfa64b12e6.jpg
# Padded + updated: d9dc633e-a6a0e7b5751fc9c52f57db9d9af1a3b.jpg
# Padded + updated: dae4eb28-0ecf0bdd92a24d3c672a8642f038eb7.jpg
# Padded + updated: daf2dbc1-ef0ebf82c4513d26436a4a783689b52.jpg
# Padded + updated: dcae8159-5c4764ec-IMG_20250427_165350.jpg
# Padded + updated: e1e979fd-IMG_20250504_162205.jpg
# Padded + updated: e392d9a8-IMG_20250515_114619.jpg
# Padded + updated: e4c37e4c-20250510_183846.jpg
# Padded + updated: e82228c3-8c8cf435-IMG_20250427_161937.jpg
# Padded + updated: ecad11cf-IMG_20250503_141619.jpg
# Padded + updated: edbc704d-IMG_20250504_163557.jpg
# Padded + updated: f076b742-IMG_20250503_134443.jpg
# Padded + updated: f3e49233-e0a021f2f5404cc6ad58076b9272d16.jpg
# Padded + updated: f4ffa216-b268f0be58599915b32abe1a2dcf9b8.jpg
# Padded + updated: f586f394-3549566f-IMG_20250427_165239.jpg
# Padded + updated: f60e3b91-b268f0be58599915b32abe1a2dcf9b8.jpg
# Padded + updated: f7dfa880-8a90af898814d53797d973d0ef10aae.jpg
# Padded + updated: f81637fb-IMG_20250515_114637.jpg
# Padded + updated: f8a0f89d-2695bfce-IMG_20250427_165030.jpg
# Padded + updated: ff00ac4b-c49542e6fee22cd5f4afa4df049327d.jpg
